# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/faisal-0065/flyrank-ml-internship/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %% [markdown]
# I will use **classification**. The goal is to identify the direction of content performance. This can help identify content that may need attention and prioritize it for review.

# %%
print("Task type: Classification")
print("Target: trend_direction")
# Out:
# Task type: Classification
# Target: trend_direction

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %% [markdown]
# My target is **trend_direction**. It is an observed outcome in the dataset that shows the direction of content performance. I will use this observed outcome instead of creating my own label.

# %%
import pandas as pd

df = pd.read_csv(csv_path)

print("Dataset loaded successfully!")
print("Dataset shape:", df.shape)
# Out:
# Dataset loaded successfully!
# Dataset shape: (30000, 44)

# %%
print("Target distribution:")
print(df["trend_direction"].value_counts(dropna=False))
# Out:
# Target distribution:
# trend_direction
# down      16262
# stable     5962
# up         4388
# new        2236
# flat       1152
# Name: count, dtype: int64

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %% [markdown]
# I will use **ROC-AUC** as the main success metric. A higher ROC-AUC means the model is better at separating declining content from non-declining content.

# %%
print("Success metric: ROC-AUC")
print("Higher ROC-AUC indicates better classification performance.")
# Out:
# Success metric: ROC-AUC
# Higher ROC-AUC indicates better classification performance.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %% [markdown]
# The unit of analysis is **one content item**. Each row represents one piece of content with its search, traffic, engagement, freshness, and trend information.

# %%
lane_cols = [
    "content_id",
    "search_volume",
    "competition",
    "word_count",
    "content_age_days",
    "impressions_90d",
    "clicks_90d",
    "sessions_90d",
    "ctr",
    "avg_position",
    "engagement_rate",
    "trend_direction"
]

lane_df = df[lane_cols].copy()

print("Lane dataframe shape:", lane_df.shape)

display(lane_df.head())
# Out:
# Lane dataframe shape: (30000, 12)
#              content_id  search_volume  competition  word_count  \
# 0  content_304f48230142           10.0         0.67      3221.0
# 1  content_a1fb4e703a9e           90.0         0.01      2481.0
# 2  content_9aa793d4d895            0.0         0.00      3515.0
# 3  content_331d6c4de07b           10.0         0.00         NaN
# 4  content_d99b7a2d90ca            0.0         0.00      2803.0
#
#    content_age_days  impressions_90d  clicks_90d  sessions_90d   ctr  \
# 0               187             3803          29            17  0.76
# 1               445            15320           7             9  0.05
# 2               141            12581          11            11  0.09
# 3               463            11751          58            78  0.49
# 4               263            19140          24           145  0.13
#
#    avg_position  engagement_rate trend_direction
# 0          10.6             5.88            down
# ...

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %% [markdown]
# Content performance depends on many signals, such as search volume, competition, traffic, clicks, engagement, content age, and position. A simple if-statement would not handle these signals well together. ML can learn patterns from several variables and provide directional decision support.

# %%
features = [
    "search_volume",
    "competition",
    "word_count",
    "content_age_days",
    "impressions_90d",
    "clicks_90d",
    "sessions_90d",
    "ctr",
    "avg_position",
    "engagement_rate"
]

print("Number of potential input features:", len(features))
print("\nFeatures:")
for feature in features:
    print("-", feature)
# Out:
# Number of potential input features: 10
#
# Features:
# - search_volume
# - competition
# - word_count
# - content_age_days
# - impressions_90d
# - clicks_90d
# - sessions_90d
# - ctr
# - avg_position
# - engagement_rate
