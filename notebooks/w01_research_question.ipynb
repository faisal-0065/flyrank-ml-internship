# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/faisal-0065/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# My lane is **content performance trend classification**. I chose this because the dataset contains historical content performance and trend information. This can help identify content that may need attention and prioritize it for review.

# %%
print("Dataset shape:", df.shape)
print("Target column:", "trend_direction")
# Out:
# Dataset shape: (30000, 44)
# Target column: trend_direction

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# The main decision is **which content should be reviewed first**. A content or SEO team can use the results to prioritize pages for further review. A wrong recommendation could waste time by prioritizing content that does not need attention, or miss content that needs review.

# %%
print("Number of content items:", df["content_id"].nunique())
print("Number of clients:", df["client_id"].nunique())
# Out:
# Number of content items: 30000
# Number of clients: 32

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %% [markdown]
# For now, don't write the numbers manually because we should use numbers directly from your dataset.

# %%
print("Total content items:", df["content_id"].nunique())

print("Average search volume:", round(df["search_volume"].mean(), 2))

print("Trend direction distribution:")
print(df["trend_direction"].value_counts())
# Out:
# Total content items: 30000
# Average search volume: 158.88
# Trend direction distribution:
# trend_direction
# down      16262
# stable     5962
# up         4388
# new        2236
# flat       1152
# Name: count, dtype: int64

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# This work can find patterns in the available data and give useful insights about content performance. It can help identify which content is doing well, which is declining, and which content may need review.
#
# However, it cannot prove that one specific change caused a result. It also cannot predict exactly what Google will rank or how Google's algorithm will behave.
#
# The results should be used as **guidance and decision support**, not as a guarantee.

# %%
print("Target column:", "trend_direction")
print("Target values:", df["trend_direction"].dropna().unique())
# Out:
# Target column: trend_direction
# Target values: ['down' 'stable' 'new' 'up' 'flat']
